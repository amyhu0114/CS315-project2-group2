# %% [markdown]
# **To use the hashformers package, the runtime must be a GPU**

# %%
# !pip install hashformers
# Out:
# Requirement already satisfied: hashformers in /usr/local/lib/python3.10/dist-packages (2.0.0)
# Requirement already satisfied: minicons in /usr/local/lib/python3.10/dist-packages (from hashformers) (0.2.41)
# Requirement already satisfied: twitter-text-python in /usr/local/lib/python3.10/dist-packages (from hashformers) (1.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from hashformers) (1.5.3)
# Requirement already satisfied: accelerate<0.26.0,>=0.25.0 in /usr/local/lib/python3.10/dist-packages (from minicons->hashformers) (0.25.0)
# Requirement already satisfied: openai<0.29.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from minicons->hashformers) (0.28.1)
# Requirement already satisfied: pillow<11.0.0,>=10.2.0 in /usr/local/lib/python3.10/dist-packages (from minicons->hashformers) (10.2.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from minicons->hashformers) (8.2.3)
# Requirement already satisfied: torch<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from minicons->hashformers) (2.2.1+cu121)
# Requirement already satisfied: transformers<5.0.0,>=4.30.0 in /usr/local/lib/python3.10/dist-packages (from minicons->hashformers) (4.38.2)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.7 in /usr/local/lib/python3.10/dist-packages (from minicons->hashformers) (1.26.18)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->hashformers) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->hashformers) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->hashformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate<0.26.0,>=0.25.0->minicons->hashformers) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate<0.26.0,>=0.25.0->minicons->hashformers) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate<0.26.0,>=0.25.0->minicons->hashformers) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate<0.26.0,>=0.25.0->minicons->hashformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate<0.26.0,>=0.25.0->minicons->hashformers) (0.4.2)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai<0.29.0,>=0.28.0->minicons->hashformers) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai<0.29.0,>=0.28.0->minicons->hashformers) (4.66.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai<0.29.0,>=0.28.0->minicons->hashformers) (3.9.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->hashformers) (1.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->minicons->hashformers) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->minicons->hashformers) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->minicons->hashformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->minicons->hashformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->minicons->hashformers) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->minicons->hashformers) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->minicons->hashformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->minicons->hashformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->minicons->hashformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->minicons->hashformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->minicons->hashformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->minicons->hashformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->minicons->hashformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->minicons->hashformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->minicons->hashformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->minicons->hashformers) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->minicons->hashformers) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->minicons->hashformers) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<3.0.0,>=2.0.0->minicons->hashformers) (12.4.99)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.30.0->minicons->hashformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.30.0->minicons->hashformers) (0.15.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai<0.29.0,>=0.28.0->minicons->hashformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai<0.29.0,>=0.28.0->minicons->hashformers) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai<0.29.0,>=0.28.0->minicons->hashformers) (2024.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai<0.29.0,>=0.28.0->minicons->hashformers) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai<0.29.0,>=0.28.0->minicons->hashformers) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai<0.29.0,>=0.28.0->minicons->hashformers) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai<0.29.0,>=0.28.0->minicons->hashformers) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai<0.29.0,>=0.28.0->minicons->hashformers) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai<0.29.0,>=0.28.0->minicons->hashformers) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<3.0.0,>=2.0.0->minicons->hashformers) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<3.0.0,>=2.0.0->minicons->hashformers) (1.3.0)

# %%
from hashformers import TransformerWordSegmenter as WordSegmenter
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
import tensorflow as tf
import tensorflow_hub as hub
import plotly.express as px
import json
import re
import random

# %%
ws = WordSegmenter(
    segmenter_model_name_or_path="distilgpt2",
    segmenter_model_type="incremental",
    reranker_model_name_or_path="distilbert-base-uncased",
    reranker_model_type="masked",
    segmenter_gpu_batch_size=1,
    reranker_gpu_batch_size=2000
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
# Mount Drive
from google.colab import drive
from google.colab import files
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('drive/MyDrive/results.csv')

# %%
df = pd.concat([df, df2])

# %%
df = df[df['video_locationcreated'] == 'US']

# %%
df.head()
# Out:
#               video_id      video_timestamp  video_duration  \
# 0  7315561816673750318  2023-12-22T18:16:20            18.0
# 1  7315561816673750318  2023-12-22T18:16:20            18.0
# 2  7315561816673750318  2023-12-22T18:16:20            18.0
# 3  7315561816673750318  2023-12-22T18:16:20            18.0
# 4  7315561816673750318  2023-12-22T18:16:20            18.0
#
#   video_locationcreated                                    suggested_words  \
# 0                    US  flipnote, flipnote animation, asdf movie, flip...
# 1                    US  flipnote, flipnote animation, asdf movie, flip...
# 2                    US  flipnote, flipnote animation, asdf movie, flip...
# 3                    US  flipnote, flipnote animation, asdf movie, flip...
# 4                    US  flipnote, flipnote animation, asdf movie, flip...
#
#    video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 0        3500000.0           39500.0             10800.0       18700000.0
# 1        3500000.0           39500.0             10800.0       18700000.0
# 2        3500000.0           39500.0             10800.0       18700000.0
# 3        3500000.0           39500.0             10800.0       18700000.0
# 4        3500000.0           39500.0             10800.0       18700000.0
#
#         video_description  video_is_ad  video_stickers  author_username  \
# 0  Bonus flipnote for you        False             NaN  zanelittlemusic
# 1  Bonus flipnote for you        False             NaN  zanelittlemusic
# 2  Bonus flipnote for you        False             NaN  zanelittlemusic
# 3  Bonus flipnote for you        False             NaN  zanelittlemusic
# 4  Bonus flipnote for you        False             NaN  zanelittlemusic
#
#    author_name  author_followercount  author_followingcount  \
# 0  Zane Little                   NaN                    NaN
# 1  Zane Little                   NaN                    NaN
# 2  Zane Little                   NaN                    NaN
# 3  Zane Little                   NaN                    NaN
# 4  Zane Little                   NaN                    NaN
#
#    author_heartcount  author_videocount  author_diggcount  author_verified
# 0                NaN                NaN               NaN            False
# 1                NaN                NaN               NaN            False
# 2                NaN                NaN               NaN            False
# 3                NaN                NaN               NaN            False
# 4                NaN                NaN               NaN            False

# %%
import random
random.seed(42)

# %%
def get_hashtags(my_string):
  if isinstance(my_string, str):
    return re.findall(r'#(\S+)', my_string.lower())
  return []

# %%
def get_segments(my_string):
  if my_string == []:
    return []
  if isinstance(my_string, str):
    my_string = [my_string]
  return ws.segment(my_string)

# %%
df['hashtags'] = df.video_description.apply(get_hashtags)

# %%
myDF = df[["video_id", "author_username", "video_description",
                "hashtags", "suggested_words"]].copy()

# %%
myDF.shape
# Out:
# (5411, 5)

# %%
mask = myDF['hashtags'].apply(lambda x: len(x) > 0)  # Check if each list is not empty
filt_dta = myDF[mask]

# %%
filt_dta.shape
# Out:
# (4391, 5)

# %%
all_hash = filt_dta['hashtags'].tolist()
result = []
trash = [result.extend(el) for el in all_hash]

# %%
result = list(set(result))
print(len(result))
# Out:
# 17568

# %%
hashed = []
for word in result:
  if word == "":
    continue
  word2 = word.split('#')
  if len(word2) <= 1:
    word2 = word2[0]
  else:
    word2 = ' '.join(word2)
  try:
    if word2[0] != '#':
      word2 = '#' + word
    hashed.append(word2)
  except:
    print(f"Something went wrong with {word}")
    continue

# %%
len(result)
# Out:
# 17568

# %%
my_sample = random.sample(result, 250)

# %%
segmentations = ws.segment(my_sample, steps=10, use_reranker=False)

# %%
segmentations
# Out:
# ['avatar the last airbender movie',
#  'stitch',
#  'viral',
#  'fyp',
#  'broskination',
#  'santagato studios',
#  'poetry',
#  '40s',
#  'vienna travel',
#  'charlidamelio',
#  'green screen',
#  'fyp',
#  'mechanical engineering',
#  'weddingday',
#  'yiruma',
#  'ivf',
#  'cap cut template',
#  'reddit',
#  'patrick jadams',
#  'native tiktok',
#  'talia is not sleepy',
#  'green screen',
#  'royalnews',
#  'anime edit',
#  'pa',
#  'starwars',
#  'date',
#  'fyp',
#  'con law',
#  'jamescameron',
#  'green screen',
#  'stem',
#  'cs',
#  'fyp',
#  'wendy',
#  'fed is best',
#  'queer wedding',
#  'dress',
#  'first gen',
#  'for you',
#  'first gen',
#  'movie',
#  'weeb',
#  'for you',
#  'bedroom decor',
#  'ni_ki',
#  'french',
#  'walker',
#  'musec reacts',
#  'reddit',
#  'funny',
#  'spoilers',
#  'urban design',
#  'mit student',
#  'reddit',
#  'for you page',
#  'engineering student',
#  'guts tour',
#  'dune 2',
#  'an aerobic fermentation',
#  'fy',
#  'royal drama',
#  'ambani wedding',
#  'fyp',
#  'hermanas',
#  'imogenkeeper',
#  'netflix recommendation',
#  'newgirlschmidt',
#  'medical school',
#  'fyy',
#  'for you',
#  'green screen',
#  'chinese new year',
#  'starter',
#  'bbm',
#  'fyp',
#  'percyjackson and the olympians',
#  'zerocon24',
#  'kelsey',
#  'kyliejenner',
#  'lana',
#  'bachelor nation 🌹',
#  'crochet top',
#  'twitter',
#  'reddit readings',
#  'single dad life',
#  'tumblr aesthetic',
#  'biglaw',
#  'katara',
#  'loss',
#  'shapershifter',
#  '777',
#  'celebrity blind items',
#  'mit',
#  'teacher pay',
#  'chinese adoption',
#  'childhood',
#  'f y p シ',
#  'indian daughter',
#  'the bachelor abc',
#  'srilankan',
#  'candycrush',
#  'cap cut',
#  'youth pastor wife',
#  'daisy the bachelor',
#  'world athletics',
#  'standup',
#  'spanish teacher',
#  'ballet things',
#  'pre dental',
#  'tyler',
#  'programming',
#  'me xico magico',
#  'tiktok',
#  'terri joe',
#  'peacemaker',
#  'vsp',
#  'fyp',
#  'nailsart',
#  'mrbeast chocolate',
#  'harry james potter',
#  'get through me',
#  'aga cooker',
#  'girls under 25',
#  'aang',
#  'viral',
#  'for you page',
#  'personal finance',
#  'stpattysday',
#  'reddit story time',
#  'dridriss',
#  'ad',
#  'devinbooker kendalljenner',
#  'residency',
#  'ready for college',
#  'pre vacation prep',
#  'california',
#  'dreamcosplayminecraft',
#  'summer intern',
#  'neuroscience',
#  'people',
#  'fyp',
#  'rholsc',
#  'annieelise',
#  'refybeauty',
#  'today show',
#  'billionaire',
#  'get him back',
#  'tellthebeees',
#  'theatretok',
#  'archeology',
#  'bobbi althoff',
#  'freechani',
#  'intern',
#  'xyz bca',
#  'kelly likes shoes',
#  'vote blue',
#  'caribbean',
#  'common app',
#  'traffic engineering',
#  'savings tips',
#  'f y p シ゚ viral',
#  'dogcute',
#  'massachusetts',
#  'anakin skywalker',
#  'california',
#  'buss sin',
#  'academic weapon',
#  'poemascortos',
#  'wharton',
#  'law school admissions tips',
#  'blow this up for me',
#  'avatar the last airbender',
#  'quittok',
#  'blacktiktok',
#  'vote',
#  'anantambani',
#  'throwback',
#  'covergirlpartner',
#  'the bachelor',
#  'show',
#  'movie',
#  'zacefron',
#  'f y p シ',
#  'fyp',
#  'bleachers',
#  'katie gavin muna',
#  'ulta must have s',
#  'mother of junk',
#  'dc',
#  'annabethchase',
#  'gabby',
#  'dating',
#  'bobmenendez',
#  'modeling',
#  'childfree women',
#  'paul',
#  'trending',
#  'thin lips',
#  'katara',
#  'ockyway',
#  'pain',
#  'pointe shoes',
#  'memecut',
#  'muna',
#  'film',
#  'naomi campbell',
#  'brookeschofield',
#  'thebarkleys',
#  'back on 74 edit',
#  'stitch',
#  'hinge',
#  'jogo',
#  'wedding impossible',
#  'unitedkingdom',
#  'doglife',
#  'for you',
#  'hockey is the best 🏒🥅',
#  'human resources life',
#  'blackdoctor',
#  'bodenslagledmd',
#  'batman',
#  'long video',
#  'mrbeastchallenge',
#  'mit',
#  'womeninstem',
#  'french',
#  'for you page',
#  'binghamton',
#  'moody',
#  'fyp',
#  'class',
#  'relationship',
#  'fyp',
#  'fyp',
#  'abc news',
#  'dylan mulvaney',
#  'tiktok',
#  'fyp',
#  'toph',
#  'f y p シ',
#  'web weaving slideshow',
#  'trending',
#  'rage against the machine fan',
#  'polite society',
#  'college decision',
#  'lab puppy',
#  'house atreides',
#  'snl',
#  'animal crossing']

# %%
segs = []
for word in segmentations:
  if "#" in word:
    word = word.split('#')
    if len(word) > 1:
      segs.extend(word)
  else:
    segs.append(word)

# %%
segs = segs + ['palestine', 'wsj', 'artists 4 ceasefire','boycott','legend', 'icon','broken system', 'farsi', 'egyptian',
               'paki', 'pakistani', 'hijabi problems', 'indian tok','airforce', 'marines', 'slavic', 'tibetan']
segs = segs + ['slavic', 'tibetan']

# %%
segs = list(set(segs))

# %%
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# %%
embeddings=embed(segs)

# %%
len(embeddings)
# Out:
# 525

# %%
k = 25
kmeans = KMeans(n_clusters=k, random_state=42)
clusters = kmeans.fit_predict(embeddings)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %%
all_clusters = []
for i in range(25):
  print(f"Cluser {i}")
  cluster_words = {segs[j] for j in range(len(segs)) if clusters[j] == i}
  all_clusters.append(cluster_words)
  print(cluster_words)
# Out:
# Cluser 0
# {'web weaving slideshow', 'film', 'movie', 'cap cut', 'bedroom decor', 'cap cut template', 'green screen'}
# Cluser 1
# {'dating', 'human resources life', 'celebrity blind items', 'childfree women', 'anime edit', 'polite society', 'single dad life', 'girls under 25', 'date', 'relationship'}
# Cluser 2
# {'poemascortos', 'bobmenendez', 'shapershifter', 'broskination', 'ockyway', 'kyliejenner', 'nailsart', 'newgirlschmidt', 'dogcute', 'fyp', 'imogenkeeper', 'biglaw', 'blacktiktok', 'jamescameron', 'freechani', 'annieelise', 'womeninstem', 'thebarkleys', 'royalnews', 'candycrush'}
# Cluser 3
# {'slavic', 'weeb', 'pakistani', 'srilankan', 'paki'}
# Cluser 4
# {'stpattysday', 'zerocon24', 'me xico magico', 'walker', 'savings tips', 'mother of junk', 'patrick jadams', 'jogo', 'artists 4 ceasefire'}
# Cluser 5
# {'zacefron', 'dreamcosplayminecraft', 'memecut', 'quittok', 'hermanas', '40s', 'charlidamelio', 'anantambani', 'cs', 'wsj', 'rholsc', 'refybeauty', 'devinbooker kendalljenner', 'covergirlpartner', 'doglife', 'dc', 'tellthebeees', 'yiruma', 'vsp', 'weddingday'}
# Cluser 6
# {'indian daughter', 'chinese adoption', 'hijabi problems', 'indian tok', 'chinese new year', 'native tiktok'}
# Cluser 7
# {'bachelor nation 🌹', 'the bachelor abc', 'xyz bca', 'daisy the bachelor', 'abc news', 'terri joe', 'the bachelor', 'bbm'}
# Cluser 8
# {'thin lips', 'santagato studios', 'ballet things', 'world athletics', 'crochet top', 'an aerobic fermentation', 'tumblr aesthetic', 'animal crossing', 'pointe shoes', 'hockey is the best 🏒🥅'}
# Cluser 9
# {'binghamton', 'mit', 'california', 'pa', 'massachusetts', 'moody'}
# Cluser 10
# {'ready for college', 'college decision', 'pre vacation prep', 'lab puppy', 'ulta must have s'}
# Cluser 11
# {'batman', 'throwback', 'funny', 'reddit', 'reddit readings', 'reddit story time', 'people', 'childhood', 'class', 'icon', 'twitter', 'standup', 'long video', 'today show', 'first gen'}
# Cluser 12
# {'katara', 'avatar the last airbender movie', 'toph', 'avatar the last airbender', 'aang', 'anakin skywalker'}
# Cluser 13
# {'rage against the machine fan', 'loss', 'vote', 'spoilers', 'vote blue', 'back on 74 edit'}
# Cluser 14
# {'billionaire', 'queer wedding', 'wharton', 'wedding impossible', 'youth pastor wife', 'ambani wedding', 'airforce', 'royal drama'}
# Cluser 15
# {'tiktok', 'show', 'boycott', 'stitch', 'pre dental', 'broken system', 'ivf', 'musec reacts', 'aga cooker', 'vienna travel', 'dress', 'modeling', 'guts tour', 'pain', 'mrbeastchallenge', 'fy', 'buss sin', 'tibetan', 'muna', 'bleachers', 'mrbeast chocolate', 'starter', 'blackdoctor', 'peacemaker'}
# Cluser 16
# {'paul', 'archeology', 'palestine', 'french', 'farsi', 'unitedkingdom', 'marines', 'poetry', 'spanish teacher', 'caribbean', 'egyptian', 'netflix recommendation'}
# Cluser 17
# {'for you', 'for you page'}
# Cluser 18
# {'get through me', 'blow this up for me', 'get him back', 'fed is best'}
# Cluser 19
# {'kelly likes shoes', 'lana', 'talia is not sleepy', 'katie gavin muna', 'ni_ki', 'percyjackson and the olympians', 'kelsey', 'gabby', 'naomi campbell', 'dylan mulvaney', 'wendy', 'tyler', 'bobbi althoff'}
# Cluser 20
# {'teacher pay', 'urban design', 'mechanical engineering', 'medical school', 'personal finance', 'programming', 'academic weapon', 'engineering student', 'residency', 'intern', 'summer intern', 'law school admissions tips', 'neuroscience', 'traffic engineering', 'stem', 'mit student'}
# Cluser 21
# {'dune 2', 'starwars', 'house atreides', 'harry james potter'}
# Cluser 22
# {'hinge', 'snl', 'ad', 'trending', 'viral'}
# Cluser 23
# {'f y p シ', 'f y p シ゚ viral'}
# Cluser 24
# {'brookeschofield', 'dridriss', '777', 'fyy', 'common app', 'bodenslagledmd', 'con law', 'annabethchase', 'theatretok', 'legend'}

# %%
tsne = TSNE(n_components=2, random_state=42)
tsne_results = tsne.fit_transform(embeddings)

# Step 3: Create a pandas dataframe
df = pd.DataFrame(tsne_results,
                  columns=['tsne_1', 'tsne_2'])
df['hashtag'] = segs

# Step 4: Use plotly to visualize it
fig = px.scatter(df, x='tsne_1', y='tsne_2', text='hashtag')
fig.update_traces(textposition='top center', mode='markers+text', textfont=dict(size=6))
fig.update_layout(title='Embeddings of TikTok News Hashtags')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="657a63a0-819d-4033-a537-cabaac05ee1c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("657a63a0-819d-4033-a537-cabaac05ee1c")) {                    Plotly.newPlot(                        "657a63a0-819d-4033-a537-cabaac05ee1c",                        [{"hovertemplate":"tsne_1=%{x}\u003cbr\u003etsne_2=%{y}\u003cbr\u003ehashtag=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":["film","billionaire","the bachelor abc","slavic","ballet things","777","percyjackson and the olympians","bobmenendez","common app","engineering student","dreamcosplayminecraft","show","farsi","residency","intern","vote blue","bbm","legend","royal drama","egyptian","mit student","for you page","stpattysday","aga cooker","talia is not sleepy","medical school","40s","charlidamelio","dress","anantambani","annabethchase","jogo","ni_ki","pain","biglaw","pa","spoilers","tyler","girls under 25","muna","bachelor nation \ud83c\udf39","chinese adoption","urban design","covergirlpartner","katie gavin muna","doglife","thebarkleys","icon","pakistani","yiruma","lab puppy","f y p \u30b7\u309a viral","peacemaker","weddingday","artists 4 ceasefire","throwback","tiktok","get through me","childfree women","bedroom decor","shapershifter","poetry","ambani wedding","pointe shoes","relationship","brookeschofield","ockyway","vienna travel","f y p \u30b7","loss","personal finance","cap cut template","anime edit","modeling","single dad life","animal crossing","dogcute","imogenkeeper","teacher pay","avatar the last airbender movie","wsj","archeology","palestine","avatar the last airbender","pre vacation prep","bodenslagledmd","aang","chinese new year","twitter","wedding impossible","harry james potter","massachusetts","con law","date","annieelise","tibetan","dridriss","rage against the machine fan","california","xyz bca","ready for college","youth pastor wife","green screen","tumblr aesthetic","dating","traffic engineering","candycrush","netflix recommendation","thin lips","reddit story time","terri joe","savings tips","class","dylan mulvaney","long video","broken system","native tiktok","today show","stem","first gen","memecut","get him back","binghamton","zerocon24","mechanical engineering","mit","reddit readings","kelsey","academic weapon","childhood","marines","an aerobic fermentation","kyliejenner","nailsart","law school admissions tips","neuroscience","airforce","viral","fyp","paul","kelly likes shoes","fed is best","batman","lana","crochet top","refybeauty","srilankan","fy","spanish teacher","patrick jadams","buss sin","freechani","blow this up for me","womeninstem","bleachers","dc","walker","fyy","theatretok","hijabi problems","naomi campbell","royalnews","unitedkingdom","anakin skywalker","blackdoctor","poemascortos","web weaving slideshow","katara","funny","zacefron","reddit","hinge","people","abc news","stitch","wharton","boycott","pre dental","wendy","broskination","ad","trending","moody","celebrity blind items","indian daughter","starwars","ivf","movie","musec reacts","hermanas","world athletics","programming","quittok","human resources life","snl","standup","polite society","newgirlschmidt","caribbean","house atreides","bobbi althoff","guts tour","hockey is the best \ud83c\udfd2\ud83e\udd45","dune 2","cs","queer wedding","me xico magico","rholsc","cap cut","french","daisy the bachelor","blacktiktok","college decision","mother of junk","summer intern","mrbeastchallenge","ulta must have s","jamescameron","back on 74 edit","paki","devinbooker kendalljenner","santagato studios","vote","toph","gabby","mrbeast chocolate","tellthebee ...

# %%
df.shape
# Out:
# (233, 3)

# %%
tsne = TSNE(n_components=2, random_state=42)
tsne_results = tsne.fit_transform(embeddings)

# Step 3: Create a pandas dataframe
df = pd.DataFrame(tsne_results,
                  columns=['tsne_1', 'tsne_2'])
df['hashtag'] = segmentations

# Step 4: Use plotly to visualize it
fig = px.scatter(df, x='tsne_1', y='tsne_2', text='hashtag')
fig.update_traces(textposition='top center', mode='markers+text', textfont=dict(size=6))
fig.update_layout(title='Embeddings of TikTok News Hashtags')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="be5d0704-72b3-40d2-b68d-761f30fae7b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be5d0704-72b3-40d2-b68d-761f30fae7b3")) {                    Plotly.newPlot(                        "be5d0704-72b3-40d2-b68d-761f30fae7b3",                        [{"hovertemplate":"tsne_1=%{x}\u003cbr\u003etsne_2=%{y}\u003cbr\u003ehashtag=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":["lacotorrisapodcast","outside hitter","ancestry results","barbie","acapella","sillycars","miss universe mexico","realhousewivesoftiktok","founder story","biscuit","awards","snoopy collection","post pandemic","harry james potter","airplane","meg","grwm outfit","newsattiktok","bsa baruch","fashion opinions","joshpeck","fanfic tiktok","calico critter","new grad","hippo baby","food as mr","bipocscientist","story time grwm","fall lip combo","soup recipe","anitkok","matthewperry","fran\u00e7ais","hermes etiquette","wellesleycollege","funding","arachne","djs_lovers","four you page","girltok","heartbroken","congress","wasian","forced friendship","culinary school","90 and still going","pittie","grupo frontera","patmcgrath","miltok","lip liner tutorial","syracuse university","firelordozai","plus size shapewear","doilool my age","acubi","r2bball","weekend vibes","what i ate this week","viral edits","tara yummy","aguascalientes","dallasbarbers","bretcrow","ragtime","weekends with adele","daydreamers with adele","classism","frp","abercrombie jeans","stem education","beginner lashes","cake by the ocean","pregnancy announcement","reality tv","lol","third grade music","skatergirl","dishoom","stark","burke ramsey","job hunting tips","plus size outfit","beaver","streamer","bellaswan","verbalase","kingscup","cyst","sti","genchem2","butter chicken","lasik eye correction","graveyard","free","do\u00f1a silvia y itati","jaylor","adidas campus00s","indian wedding season","sports","rot","fairmont","drinking culture","movie fyp","motherhood unfiltered","beauty as mr","sabbath","remote jobs 2024","plaid outfits","maybelline","uoff","jewlerymaking","bobby deol entry song","law student things","paul atreides and lady jessica","bad friendships","govtechjobs","lara dutta","rekha","cb to","taylor travis","samoatiktok","guitaristoftiktok","techjobs","cemetery wandering","vocal exercise","veiledchristian","hotpockets","49ersfaithfull","owenwilson","temu viral","boohbahs","hype","etsy finds","cultural appreciation","bravo tv addict","lo real paris partner","fashion commentator","girls5eva","class 101","training season","tbi awareness","life coach","smooth","eye contact","catfish makeup","ciggarettes after ex","zombie apocalypse","barbara sprouse","mind blown","minnesota","iris van herpen","cinephile","rick riordan universe","vienna","coquette makeup","deglam","students","margaretzhang","nighttime routine","viral #greenscreen","cnaatl","pilates","cost of living","college decision reaction","desi community","patient care","bangla house","savegaza","bishal","cerveza","trump","buzzed","hoo","pop culture","kid germ survivor","kiseniu","corporate","college soccer","geography","inner child","crisapple","brettcooper","princess and the pauper","dog humor","bn","team acne","blue ivy","swades","vendors","htgawmedit","grocery coupons","tiktok shop valentines day","lotion","ariana grande wicked","diaries","toddler hairstyles","goth","sustainability","centralflorida","2014","we the kings","collaboration","broadway","drkalimd","husband","dijon music","beck","nursings ### emotional control","paralyzed","stem life","ockyway","disneydescendants","smellgood","lunar  ...

# %%
myDF = df[["video_id", "author_username", "video_description",
                "hashtags", "suggested_words"]].copy()

# %%
news = pd.read_csv('news.csv')

# %%
news.head()
# Out:
#   Hashtag name                                            Link Initials
# 0   uspolitics   https://www.tiktok.com/tag/uspolitics?lang=en       EM
# 1  republicans  https://www.tiktok.com/tag/republicans?lang=en       EM
# 2   republican   https://www.tiktok.com/tag/republican?lang=en       EM
# 3     democrat     https://www.tiktok.com/tag/democrat?lang=en       EM
# 4    democrats    https://www.tiktok.com/tag/democrats?lang=en       EM

# %%
news_hash = news['Hashtag name'].to_list()

# %%
set(news_hash).intersection(set(segs))
# Out:
# {'blacklivesmatter',
#  'palestine',
#  'sports',
#  'unemployment',
#  'vote',
#  'worldnews'}

# %%
headlines = pd.read_csv('output.csv')

# %%
headlines.head()
# Out:
#    Unnamed: 0                                                  0
# 0           0  Sheriff Recorded Making Inflammatory Comments ...
# 1           1  Governor Vetoes Louisiana’s Ban on Transition ...
# 2           2  Robert Kennedy Jr. Reports Income of $7.8 Million
# 3           3  Coast Guard Apologizes for Covering Up Long Hi...
# 4           4                            Certain Surprise Party?

# %%
headline = headlines.iloc[:,1].to_list()

# %%
headline = random.sample(headline, 25)

# %%
len(headline)
# Out:
# 29780

# %%
em_all = embed(headline + segs[-300:])

# %%
len(em_all)
# Out:
# 625

# %%
df
# Out:
#         tsne_1     tsne_2
# 0    -9.999284 -33.425861
# 1    -0.397730 -28.652657
# 2    -9.998209 -21.816757
# 3    -7.527874 -38.671719
# 4    -5.265017 -35.932163
# ..         ...        ...
# 620  -0.187387  -7.200427
# 621  -3.645554   0.518941
# 622  -3.913756   1.374411
# 623  12.512190  27.008213
# 624  11.634087  25.089376
#
# [625 rows x 2 columns]

# %%
tsne = TSNE(n_components=2, random_state=42)
tsne_results = tsne.fit_transform(em_all)

# Step 3: Create a pandas dataframe
df = pd.DataFrame(tsne_results,
                  columns=['tsne_1', 'tsne_2'])
df['hashtag'] = headline + segs[-300:]

# Step 4: Use plotly to visualize it
fig = px.scatter(df, x='tsne_1', y='tsne_2', text='hashtag')
fig.update_traces(textposition='top center', mode='markers+text', textfont=dict(size=6))
fig.update_layout(title='Embeddings of TikTok News Hashtags and Headlines')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d5156f64-7f7c-48e6-b1be-9dada7f62400" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5156f64-7f7c-48e6-b1be-9dada7f62400")) {                    Plotly.newPlot(                        "d5156f64-7f7c-48e6-b1be-9dada7f62400",                        [{"hovertemplate":"tsne_1=%{x}\u003cbr\u003etsne_2=%{y}\u003cbr\u003ehashtag=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":["Quotation of the Day: Global Shippers Again Embrace the \u2018Free Fuel\u2019","What Happened in the World of Artificial Intelligence?","Columbia University Postpones a Fund-Raiser as Divisions Over War Deepen","Christmas Moves to Dec. 25 in Ukraine, Another Rebuff of Russia","There\u2019s a Reason Hasan Minhaj\u2019s Lies Found Such a Big Audience","Catch Them if You Can","More Than 100,000 March in France Against Antisemitism","Be Not Afraid of Greatness: Take Our Shakespeare Quiz","Bears Are Having a Moment","Holiday Fireworks Worsen Air Quality Nationwide","In New York Win, Democrats Sense a Pivot on Immigration and Border Politics","After Bruising Vote, Indigenous Australians Say \u2018Reconciliation Is Dead\u2019","Thursday Briefing","Justice Dept. Watchdog Describes Unsanitary Conditions at Florida Prison","Judge Rejects Johnson & Johnson\u2019s Effort to Limit Talc-Related Suits","Supreme Court Allows Mobile Sports Bets at Florida Indian Casinos","The Hidden Places Where You Find Your People","Vase Bought at Goodwill for $3.99 Sells for More Than $100,000","Lee Hoyang, Prolific K-Pop Producer and Songwriter, Dies at 40","Can You Optimize an Orgasm?","The Best Movies and TV Shows Coming to Amazon, Hulu, Apple TV+ and More in November","Is Poor Economic Sentiment All About MAGA?","Why a Floating Speck of Metal Sent Scientists\u2019 Hearts Racing","Who Decides Penn\u2019s Future: Donors or the University?","Will Hurd, Republican Presidential Candidate, on the Issues","diy","dominic fike","bra shopping","inspirational video","trashy mcbling","antiques","meg","prof aragon","gym motivation","renaissance","i miss my ex","law school wait list","sale","stressed out","help me","try \u2764\ufe0f\u2764\ufe0f\u2764\ufe0f","soup season","notre dame","erenjaeger","big game","naev is calling \u00e6 \ud83e\udd33","sushi","hilary swank","nightly routine","stem ","study ","stem","new song","hairtiktok","jynxziclips","bhutanese","vegetarian","history facts","balloonpop","as vegas","jelinskywhy","romanroy","caught on camera","elizabetholsen","keloid","roomates","ready to match energy","girls inspire girls","rhys and","jcnaturals","got7official","the crown act","pesopluma tour","different languages","attack on titan","brand deal help","im just a girl","fridgecheck","marinette","last man on earth","singer","k 18 results","indian wedding season","andreajin","rorygilmore","arrested","latina speaking english","baby love","med school tuition","tripp photo","cleaning lady","blacklivesmatter","tinkerbell","recognition","blackowned business","for profit","stanley cup playoffs","cocktails","method products","love is blind sweden","chem","secondary","rhashad","gw law school","learn graphic design","infallible powder","el salvador","giddha","new arrivals","x by cza","adulting","im not famous","mother of junk","aesthetic edits","ilove_newyo","safaera","\ud83e\udd11\ud83e\udd19","fitness advice for beginners","catherine paiz","mft grad student","college rankings","fat babe rant","anupamaparameswaran","tiktok viral video","housing","ebaypartner","marriage life","ramya","dnd","frenchculture","vote","study abroad","follw","survivalism","mybi ...
